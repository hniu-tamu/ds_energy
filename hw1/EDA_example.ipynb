# %% [markdown]
# <a href="https://colab.research.google.com/github/hniu-tamu/ds_energy/blob/main/hw1/EDA_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Case #1 US Mass Shootings, 1982-2020: Data From Mother Jones’ Investigation
# [Link to the report](https://www.motherjones.com/politics/2012/12/mass-shootings-mother-jones-full-data/)
#
# This dataset covers the mass shooting cases in the US from 1982 to 2020.

# %%
import pandas as pd
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("https://github.com/e-zl/dswebinar/raw/master/pandas_matplotlib/session2/MJ_mass_shooting1982_2020.csv")

# %%
df.head(5)
# Out:
#                                      case                 location      date  \
# 0                   Molson Coors shooting     Milwaukee, Wisconsin   2/26/20
# 1      Jersey City kosher market shooting  Jersey City, New Jersey  12/10/19
# 2           Pensacola Naval base shooting       Pensacola, Florida   12/6/19
# 3           Odessa-Midland shooting spree            Odessa, Texas   8/31/19
# 4  Dayton entertainment district shooting             Dayton, Ohio    8/4/19
#
#                                              summary  fatalities  injured  \
# 0  Anthony Ferrill, 51, an employee armed with tw...           5        0
# 1  David N. Anderson, 47, and Francine Graham, 50...           4        3
# 2  Ahmed Mohammed al-Shamrani, A Saudi Arabian mi...           3        8
# 3  Seth A. Ator, 36, fired at police officers who...           7       25
# 4  Connor Betts, 24, died during the attack, foll...           9       27
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   case                              118 non-null    object
#  1   location                          118 non-null    object
#  2   date                              118 non-null    object
#  3   summary                           118 non-null    object
#  4   fatalities                        118 non-null    int64
#  5   injured                           118 non-null    int64
#  6   total_victims                     118 non-null    int64
#  7   location.1                        118 non-null    object
#  8   age_of_shooter                    118 non-null    object
#  9   prior_signs_mental_health_issues  118 non-null    object
#  10  mental_health_details             118 non-null    object
# ...

# %%
df.describe().T
# Out:
#                count         mean        std          min          25%  \
# fatalities     118.0     8.076271   7.943343     3.000000     5.000000
# injured        118.0    12.228814  50.678712     0.000000     1.000000
# total_victims  118.0    20.305085  56.258334     3.000000     7.000000
# latitude       118.0    37.346087   5.763058    21.320063    33.605188
# longitude      118.0   -96.510846  17.997837  -157.876462  -117.219188
# year           118.0  2008.152542  10.421565  1982.000000  1999.000000
#
#                        50%          75%          max
# fatalities        6.000000     8.750000    58.000000
# injured           3.500000    10.750000   546.000000
# total_victims    10.500000    18.000000   604.000000
# latitude         38.323367    41.518936    48.461367
# longitude       -90.537585   -81.314759   -71.075913
# year           2012.000000  2017.000000  2020.000000

# %%
df.hist(figsize=(10,10), bins=20);

# %%
df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-7-0890aefbf3d8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <ipython-input-7-0890aefbf3d8>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_c841d_row0_col0, #T_c841d_row1_col1, #T_c841d_row2_col2, #T_c841d_row3_col3, #T_c841d_row4_col4, #T_c841d_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c841d_row0_col1 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_c841d_row0_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# ...

# %% [markdown]
# ## Case #2 Wine Data Set
#
# [Link to the data set](https://archive.ics.uci.edu/ml/datasets/wine+quality)
#
# The particular dataset used in this case study is related to red variants of the Portuguese "Vinho Verde" wine. The goal is to model wine quality based on physicochemical tests.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/e-zl/dswebinar/master/pandas_matplotlib/session2/winequality-red.csv", sep=';')

# %%
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
df.hist(figsize=(10,10), bins=20);

# %%
df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-13-0890aefbf3d8>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_e9354_row0_col0, #T_e9354_row1_col1, #T_e9354_row2_col2, #T_e9354_row3_col3, #T_e9354_row4_col4, #T_e9354_row5_col5, #T_e9354_row6_col6, #T_e9354_row7_col7, #T_e9354_row8_col8, #T_e9354_row9_col9, #T_e9354_row10_col10, #T_e9354_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e9354_row0_col1, #T_e9354_row4_col11, #T_e9354_row9_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_e9354_row0_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_e9354_row0_col3, #T_e9354_row4_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_e9354_row0_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# ...

# %%
sns.pairplot(data=df, kind="scatter", vars=["fixed acidity", "citric acid", "density", "pH"], hue="quality")

# %%
sns.violinplot(data=df[["fixed acidity", "citric acid", "density", "pH"]])
# Out:
# <Axes: >

# %%
from sklearn import preprocessing

x = df.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled, columns=df.columns)

df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.247788          0.397260         0.00        0.068493   0.106845
# 1          0.283186          0.520548         0.00        0.116438   0.143573
# 2          0.283186          0.438356         0.04        0.095890   0.133556
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 4          0.247788          0.397260         0.00        0.068493   0.106845
# ...             ...               ...          ...             ...        ...
# 1594       0.141593          0.328767         0.08        0.075342   0.130217
# 1595       0.115044          0.294521         0.10        0.089041   0.083472
# 1596       0.150442          0.267123         0.13        0.095890   0.106845
# 1597       0.115044          0.359589         0.12        0.075342   0.105175
# 1598       0.123894          0.130137         0.47        0.184932   0.091820
#
# ...

# %% [markdown]
# ## Case #3 California House Price
# The California house dataset can be accessed with the scikit-learn library.

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

df=pd.DataFrame(housing.data, columns=housing.feature_names)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
df.head(5)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df.describe().T
# Out:
#               count         mean          std         min         25%  \
# MedInc      20640.0     3.870671     1.899822    0.499900    2.563400
# HouseAge    20640.0    28.639486    12.585558    1.000000   18.000000
# AveRooms    20640.0     5.429000     2.474173    0.846154    4.440716
# AveBedrms   20640.0     1.096675     0.473911    0.333333    1.006079
# Population  20640.0  1425.476744  1132.462122    3.000000  787.000000
# AveOccup    20640.0     3.070655    10.386050    0.692308    2.429741
# Latitude    20640.0    35.631861     2.135952   32.540000   33.930000
# Longitude   20640.0  -119.569704     2.003532 -124.350000 -121.800000
#
#                     50%          75%           max
# MedInc         3.534800     4.743250     15.000100
# HouseAge      29.000000    37.000000     52.000000
# AveRooms       5.229129     6.052381    141.909091
# AveBedrms      1.048780     1.099526     34.066667
# Population  1166.000000  1725.000000  35682.000000
# ...

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'MedInc'}>,
#         <Axes: title={'center': 'HouseAge'}>,
#         <Axes: title={'center': 'AveRooms'}>],
#        [<Axes: title={'center': 'AveBedrms'}>,
#         <Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'AveOccup'}>],
#        [<Axes: title={'center': 'Latitude'}>,
#         <Axes: title={'center': 'Longitude'}>, <Axes: >]], dtype=object)

# %%
df.corr().style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# <ipython-input-25-9517c8ba798e>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df.corr().style.background_gradient(cmap='coolwarm').set_precision(3)
# <style type="text/css">
# #T_e871d_row0_col0, #T_e871d_row1_col1, #T_e871d_row2_col2, #T_e871d_row3_col3, #T_e871d_row4_col4, #T_e871d_row5_col5, #T_e871d_row6_col6, #T_e871d_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e871d_row0_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e871d_row0_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_e871d_row0_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_e871d_row0_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_e871d_row0_col5 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e871d_row0_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_e871d_row0_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# ...

# %%
sns.pairplot(data=df)
